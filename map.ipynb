# %%
import folium
import webbrowser
map = folium.Map(location=[47,19])
folium.Marker(location=[47.73065185546875,19.498397827148438],popup="gép1").add_to(map)
folium.Marker(location=[47.748321533203125,19.473403930664062],popup="gép2").add_to(map)
folium.Marker(location=[45,45])
map.save("map.html")
webbrowser.open("map.html")
# Out:
# True

# %%
# ground speed

encoded_speed = 35
range_start = 13
range_stop = 38
start = 2
stop = 15
delta = 0.5

sorszam = encoded_speed-range_start
speed = delta*sorszam+start
print(speed)
# Out:
# 13.0
